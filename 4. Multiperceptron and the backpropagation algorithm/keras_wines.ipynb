# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as matplot
import keras
from sklearn.model_selection import train_test_split
from sklearn import preprocessing, metrics
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %% [markdown]
# **Ejercicio 3**
#
# El archivo Vinos.csv tiene información referida a 13 características químicas y/o visuales de varias muestras de vinos pertenecientes a 3 clases distintas.
#
# Utilice el 80% de los ejemplos del archivo Vinos.csv para entrenar multiperceptrón que sea capaz que distinguir entre las 3 clases de vinos. Observe la tasa de acierto obtenida sobre el 20% restante.

# %%
# Load dataset
df_vinos = pd.read_csv('data/wines.csv', delimiter=';')

# %%
df_train, df_test = train_test_split(df_vinos, test_size=0.6)

# %%
# Tomamos todas las columnas menos la última
X = np.array(df_train.iloc[:, 1:])
Y = np.array(df_train.iloc[:, 0:1])
encoder = preprocessing.LabelEncoder()
Y = encoder.fit_transform(Y)
# Out:
# /home/nahuel/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Create the model, create the network architecture and configure it
model = Sequential()
model.add(Dense(3, input_shape=[13], activation='sigmoid'))
model.compile(optimizer=SGD(lr=0.2), loss='mse', metrics='accuracy')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
model.fit(X, keras.utils.to_categorical(Y), epochs=30, batch_size=100)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 0s 213ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 2/30
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 3/30
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 4/30
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 5/30
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 6/30
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 7/30
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 8/30
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 9/30
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.3662
# Epoch 10/30
# ...

# %%
print("%% aciertos X_train : %.2f" % metrics.accuracy_score(Y, np.argmax(model.predict(X), axis=1)))
# Out:
# 3/3 [==============================] - 0s 1ms/step
# % aciertos X_train : 0.37

# %%
X_test = np.array(df_test.iloc[:, 1:])
Y_test = np.array(df_test.iloc[:, 0:1])
encoder = preprocessing.LabelEncoder()
Y_test = encoder.fit_transform(Y_test)
# Out:
# /home/nahuel/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print("%% aciertos X_test : %.2f" % metrics.accuracy_score(Y_test, np.argmax(model.predict(X_test), axis=1)))
# Out:
# 4/4 [==============================] - 0s 871us/step
# % aciertos X_test : 0.31
